# %% [markdown]
# # hw2: Write your own code for the Mortality Notebook

# %%
import pandas as pd

# %% [markdown]
# ## 1. (10 pts) Read the provided pickle data into mortality_data and mortality_wide

# %%
mortality_data = pd.read_pickle('mortality_data.pkl')

# %%
mortality_wide =  pd.read_pickle('mortality_wide.pkl')

# %% [markdown]
# ## 2. (2 pts) Show first 5 rows from mortality_data

# %%
mortality_data.head(5)
# Out:
#    Year  Age Group  Death Rate
# 0  1900  1-4 Years      1983.8
# 1  1901  1-4 Years      1695.0
# 2  1902  1-4 Years      1655.7
# 3  1903  1-4 Years      1542.1
# 4  1904  1-4 Years      1591.5

# %% [markdown]
# ## 3. (6 pts) Change the name of the "Age Group" colume to "AgeGroup" and “Death Rate” column to “DeathsPer100K” and show first 5 rows

# %%
mortality_data.columns=mortality_data.columns.str.replace(" ", '')
mortality_data.columns=mortality_data.columns.str.replace("DeathRate", 'DeathsPer100K')
mortality_data.head(5)
# Out:
#    Year   AgeGroup  DeathsPer100K
# 0  1900  1-4 Years         1983.8
# 1  1901  1-4 Years         1695.0
# 2  1902  1-4 Years         1655.7
# 3  1903  1-4 Years         1542.1
# 4  1904  1-4 Years         1591.5

# %% [markdown]
# ## 4. (6 pts) Display the first five rows of data from 1910 through 1920.

# %%
mortality_data.query('Year >= 1910 and Year <= 1920').head(5)
# Out:
#     Year   AgeGroup  DeathsPer100K
# 10  1910  1-4 Years         1397.3
# 11  1911  1-4 Years         1176.0
# 12  1912  1-4 Years         1094.1
# 13  1913  1-4 Years         1193.4
# 14  1914  1-4 Years         1024.2

# %% [markdown]
# ## 5. (6 pts) Display Year and DeathsPer100K columns for the age group 15-19 Years from 2010 through 2018

# %%
mortality_data.query("Year >= 2010 and Year <=2018 and AgeGroup == '15-19 Years'")[['Year','DeathsPer100K']]
# Out:
#      Year  DeathsPer100K
# 467  2010           49.4
# 468  2011           48.9
# 469  2012           47.2
# 470  2013           44.8
# 471  2014           45.5
# 472  2015           48.3
# 473  2016           51.2
# 474  2017           51.5
# 475  2018           49.2

# %% [markdown]
# ## 6. (6 pts)  Sort the DataFrame by the DeathsPer100K column in ascending sequence for AgeGroup 15-19 Years, and display the first five rows for Year and DeathsPer100K columns.

# %%
mortality_data.query("AgeGroup == '15-19 Years'")[['Year','DeathsPer100K']].sort_values(['DeathsPer100K']).head(5)
# Out:
#      Year  DeathsPer100K
# 470  2013           44.8
# 471  2014           45.5
# 469  2012           47.2
# 472  2015           48.3
# 468  2011           48.9

# %% [markdown]
# ## 7. (10 pts)  For the result in the previous problem, show the reulst so that it displays the first and last three rows of the results.

# %%
with pd.option_context('display.max_rows', 6,'display.max_columns', None):display(mortality_data)
# Out:
#      Year     AgeGroup  DeathsPer100K
# 0    1900    1-4 Years         1983.8
# 1    1901    1-4 Years         1695.0
# 2    1902    1-4 Years         1655.7
# ..    ...          ...            ...
# 473  2016  15-19 Years           51.2
# 474  2017  15-19 Years           51.5
# 475  2018  15-19 Years           49.2
#
# [476 rows x 3 columns]

# %% [markdown]
# ## 8. (6 pts)  Group the data by year, and calculate the sum of the DeathsPer100K column.

# %%
mortality_data.groupby('Year').sum('DeathsPer100K')
# Out:
#       DeathsPer100K
# Year
# 1900         3233.0
# 1901         2850.6
# 1902         2733.0
# 1903         2659.1
# 1904         2793.1
# ...             ...
# 2014           95.0
# 2015           99.5
# 2016          103.3
# 2017          102.9
# 2018           99.6
#
# [119 rows x 1 columns]

# %% [markdown]
# ## 9. (8 pts)  Display the mean, median, and sum of DeathsPer100K per each year

# %%
mortality_data.groupby('Year')[['DeathsPer100K']].agg(['mean','median','sum'])
# Out:
#      DeathsPer100K
#               mean  median     sum
# Year
# 1900       808.250  475.45  3233.0
# 1901       712.650  441.00  2850.6
# 1902       683.250  412.40  2733.0
# 1903       664.775  424.40  2659.1
# 1904       698.275  448.20  2793.1
# ...            ...     ...     ...
# 2014        23.750   19.00    95.0
# 2015        24.875   19.75    99.5
# 2016        25.825   19.95   103.3
# 2017        25.725   19.90   102.9
# 2018        24.900   19.45    99.6
#
# [119 rows x 3 columns]

# %% [markdown]
# ## 10. (2 pts)  Show first 5 rows from mortality_wide

# %%
mortality_wide.head(5)
# Out:
#    Year  01-04 Years  05-09 Years  10-14 Years  15-19 Years
# 0  1900     0.019838     0.004661     0.002983     0.004848
# 1  1901     0.016950     0.004276     0.002736     0.004544
# 2  1902     0.016557     0.004033     0.002525     0.004215
# 3  1903     0.015421     0.004147     0.002682     0.004341
# 4  1904     0.015915     0.004250     0.003052     0.004714

# %% [markdown]
# ## 11. (6 pts)  Use the describe() method to display statistical information for the numeric columns in mortality_wide. Then, add the T property to see how the display changes.

# %%
mortality_wide.describe()
# Out:
#               Year  01-04 Years  05-09 Years  10-14 Years  15-19 Years
# count   119.000000   119.000000   119.000000   119.000000   119.000000
# mean   1959.000000     0.003832     0.001173     0.000938     0.001774
# std      34.496377     0.005005     0.001275     0.000884     0.001384
# min    1900.000000     0.000240     0.000114     0.000139     0.000448
# 25%    1929.500000     0.000507     0.000240     0.000272     0.000855
# 50%    1959.000000     0.001091     0.000484     0.000446     0.001069
# 75%    1988.500000     0.005773     0.001989     0.001589     0.002837
# max    2018.000000     0.019838     0.004661     0.003751     0.007774

# %%
mortality_wide.describe().T
# Out:
#              count         mean        std          min          25%  \
# Year         119.0  1959.000000  34.496377  1900.000000  1929.500000
# 01-04 Years  119.0     0.003832   0.005005     0.000240     0.000507
# 05-09 Years  119.0     0.001173   0.001275     0.000114     0.000240
# 10-14 Years  119.0     0.000938   0.000884     0.000139     0.000272
# 15-19 Years  119.0     0.001774   0.001384     0.000448     0.000855
#
#                      50%          75%          max
# Year         1959.000000  1988.500000  2018.000000
# 01-04 Years     0.001091     0.005773     0.019838
# 05-09 Years     0.000484     0.001989     0.004661
# 10-14 Years     0.000446     0.001589     0.003751
# 15-19 Years     0.001069     0.002837     0.007774

# %% [markdown]
# ## 12. (6 pts) Display the first 10 rows of the Year and 01-04 Years columns.

# %%
mortality_wide[['Year','01-04 Years']].head(10)
# Out:
#    Year  01-04 Years
# 0  1900     0.019838
# 1  1901     0.016950
# 2  1902     0.016557
# 3  1903     0.015421
# 4  1904     0.015915
# 5  1905     0.014989
# 6  1906     0.015800
# 7  1907     0.014683
# 8  1908     0.013968
# 9  1909     0.013489

# %% [markdown]
# ## 13. (6 pts) Display the Year and 15-19 Years column for rows for the years from 2010 through 2018.

# %%
mortality_wide.query("Year>=2010 and Year<=2018")[['Year','15-19 Years']]
# Out:
#      Year  15-19 Years
# 110  2010     0.000494
# 111  2011     0.000489
# 112  2012     0.000472
# 113  2013     0.000448
# 114  2014     0.000455
# 115  2015     0.000483
# 116  2016     0.000512
# 117  2017     0.000515
# 118  2018     0.000492

# %% [markdown]
# ## 14. (10 pts) Add new columns TotalDeaths and AvgDeaths to mortality_wide. The value of this columns should be the sum and average of the values in each of the year range columns. Display the DataFrame with the new columns.

# %%
mortality_wide['TotalDeaths'] = mortality_wide['01-04 Years'] + mortality_wide['05-09 Years'] + mortality_wide['10-14 Years'] + mortality_wide['15-19 Years']
mortality_wide['AvgDeaths']=mortality_wide['TotalDeaths'] / 4
mortality_wide.head()
# Out:
#    Year  01-04 Years  05-09 Years  10-14 Years  15-19 Years  TotalDeaths  \
# 0  1900     0.019838     0.004661     0.002983     0.004848     0.032330
# 1  1901     0.016950     0.004276     0.002736     0.004544     0.028506
# 2  1902     0.016557     0.004033     0.002525     0.004215     0.027330
# 3  1903     0.015421     0.004147     0.002682     0.004341     0.026591
# 4  1904     0.015915     0.004250     0.003052     0.004714     0.027931
#
#    AvgDeaths
# 0   0.008082
# 1   0.007127
# 2   0.006832
# 3   0.006648
# 4   0.006983

# %% [markdown]
# ## 15. (10 pts) Create a line plot that shows the death rates for all age groups by year. You should use mortality_wide dataframe.

# %%
import matplotlib.pyplot as plt
mortality_wide.plot(x='Year', y=['01-04 Years','05-09 Years','10-14 Years','15-19 Years'])
plt.show()
